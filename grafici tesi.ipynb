# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np


mz = [
8,
16,
32,
48,
64,
96,
128,
256,
384,
512]

numpy_y = [
15.0341,
30.0921,
60.9012,
92.0453,
122.0273,
181.8231,
241.9010,
495.9901, 
741.8362,
1072.091]

cuda_y = [
11.8321,
14.4921,
18.7710,
22.4819,
26.9682,
35.7171,
44.4185,
79.6521,
116.6748,
152.9687]



plt.figure(figsize=(8,5), layout='constrained')

plt.plot(mz, numpy_y, label='numpy',marker = "o",linestyle='--')  
plt.plot(mz, cuda_y, label='cuda + jit',marker = "x",linestyle='-')
plt.xlabel("Numero celle lungo l'asse z")
plt.ylabel("Tempo [s]")

plt.legend();
plt.savefig("np_vs_cuda.png")
